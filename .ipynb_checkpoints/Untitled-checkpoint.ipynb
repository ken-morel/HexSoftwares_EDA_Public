# %%
using DataFrames
using CSV

# %%
function loaddata()
    CSV.read("./AB_NYC_2019.csv", DataFrame)
end
# Out:
# loaddata (generic function with 1 method)

# %%
data = loaddata()
# Out:
# 48895×16 DataFrame
#    Row │ id        name                               host_id    host_name     ⋯
#        │ Int64     String                             Int64      String?       ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │     2539  Clean & quiet apt home by the pa…       2787  John          ⋯
#      2 │     2595  Skylit Midtown Castle                   2845  Jennifer
#      3 │     3647  THE VILLAGE OF HARLEM....NEW YOR…       4632  Elisabeth
#      4 │     3831  Cozy Entire Floor of Brownstone         4869  LisaRoxanne
#      5 │     5022  Entire Apt: Spacious Studio/Loft…       7192  Laura         ⋯
#      6 │     5099  Large Cozy 1 BR Apartment In Mid…       7322  Chris
#      7 │     5121  BlissArtsSpace!                         7356  Garon
#      8 │     5178  Large Furnished Room Near B'way         8967  Shunichi
#      9 │     5203  Cozy Clean Guest Room - Family A…       7490  MaryEllen     ⋯
# ...

# %%
data.
